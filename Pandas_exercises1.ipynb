# %%
import pandas as pd

# %%
series= pd.Series(('Nik', 'p', 30, 'nik@email.com', 175))

# %%
series
# Out:
# 0              Nik
# 1                p
# 2               30
# 3    nik@email.com
# 4              175
# dtype: object

# %%
dataframe1= pd.DataFrame([('Nik', 'p', 30, 'nik@email.com', 175),
                          ('Evan', 'D', 31, 'evan@email.com', 170)])

# %%
dataframe1
# Out:
#       0  1   2               3    4
# 0   Nik  p  30   nik@email.com  175
# 1  Evan  D  31  evan@email.com  170

# %%
dataframe2= pd.DataFrame([('Nik', 'p', 30, 'nik@email.com', 175),
                          ('Evan', 'D', 31, 'evan@email.com', 170)],
                        columns = ['First Name', 'Last Initial', 'Age', 'Email', 'Weight'])
dataframe2
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            p   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
df3 = pd.DataFrame({'First Name': ['Nik', 'Evan'],
                    'Last Initial' : ['p', 'D'],
                    'Age' :[30, 31],
                    'Email': ['nik@email.com', 'evan@email.com'] ,
                    'Weight': [175,170]})

df3
# Out:
#   First Name Last Initial  Age           Email  Weight
# 0        Nik            p   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
df= pd.read_csv('cleaned_autos.csv')

# %%
df
# Out:
#                 dateCrawled                                   name  seller  \
# 0       2016-03-24 11:52:17                             Golf_3_1.6  privat
# 1       2016-03-24 10:58:45                   A5_Sportback_2.7_Tdi  privat
# 2       2016-03-14 12:52:21         Jeep_Grand_Cherokee_"Overland"  privat
# 3       2016-03-17 16:54:04                     GOLF_4_1_4__3TÜRER  privat
# 4       2016-03-31 17:25:20         Skoda_Fabia_1.4_TDI_PD_Classic  privat
# ...                     ...                                    ...     ...
# 313682  2016-03-21 09:50:58                        Mitsubishi_Cold  privat
# 313683  2016-03-14 17:48:27             Suche_t4___vito_ab_6_sitze  privat
# 313684  2016-03-05 19:56:21  Smart_smart_leistungssteigerung_100ps  privat
# 313685  2016-03-19 18:57:12     Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 313686  2016-03-20 19:41:08                 VW_Golf_Kombi_1_9l_TDI  privat
#
# ...

# %%
df.shape    # return a tuple representing thr dimensionality of the DataFrame
# Out:
# (313687, 27)

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  ...  \
# 0    480   test       Other                1993    manuell        0  ...
# 1  18300   test       coupe                2011    manuell      190  ...
# 2   9800   test         suv                2004  automatik      163  ...
# 3   1500   test  kleinwagen                2001    manuell       75  ...
# 4   3600   test  kleinwagen                2008    manuell       69  ...
#
#   postalCode             lastSeen yearOfCreation yearCrawled monthOfCreation  \
# ...

# %%
df.head(7)
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-24 11:52:17                                         Golf_3_1.6
# 1  2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 2  2016-03-14 12:52:21                     Jeep_Grand_Cherokee_"Overland"
# 3  2016-03-17 16:54:04                                 GOLF_4_1_4__3TÜRER
# 4  2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 5  2016-04-04 17:36:23  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 6  2016-04-01 20:48:51                        Peugeot_206_CC_110_Platinum
#
#    seller offerType  price abtest vehicleType  yearOfRegistration    gearbox  \
# 0  privat     Offer    480   test       Other                1993    manuell
# 1  privat     Offer  18300   test       coupe                2011    manuell
# 2  privat     Offer   9800   test         suv                2004  automatik
# ...

# %%
df.tail()    # son 5 satiri döndürür
# Out:
#                 dateCrawled                                   name  seller  \
# 313682  2016-03-21 09:50:58                        Mitsubishi_Cold  privat
# 313683  2016-03-14 17:48:27             Suche_t4___vito_ab_6_sitze  privat
# 313684  2016-03-05 19:56:21  Smart_smart_leistungssteigerung_100ps  privat
# 313685  2016-03-19 18:57:12     Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 313686  2016-03-20 19:41:08                 VW_Golf_Kombi_1_9l_TDI  privat
#
#        offerType  price   abtest vehicleType  yearOfRegistration      gearbox  \
# 313682     Offer      0  control       Other                2005      manuell
# 313683     Offer   2200     test       Other                2005  Unspecified
# 313684     Offer   1199     test      cabrio                2000    automatik
# 313685     Offer   9200     test         bus                1996      manuell
# 313686     Offer   3400     test       kombi                2002      manuell
#
# ...

# %%
df.sample()     # rastgele bir satir döndürür
# Out:
#                dateCrawled                                               name  \
# 25335  2016-04-01 12:50:19  Audi_A4_Avant_2.5_TDI_quattro_Xenon_Klimaaut._...
#
#        seller offerType  price abtest vehicleType  yearOfRegistration  \
# 25335  privat     Offer   2690   test       kombi                2002
#
#        gearbox  powerPS  ... postalCode             lastSeen yearOfCreation  \
# 25335  manuell      179  ...      39418  2016-04-07 09:17:50           2016
#
#       yearCrawled monthOfCreation monthCrawled NoOfDaysOnline  NoOfHrsOnline  \
# 25335        2016           April        April              6              9
#
#       yearsOld  monthsOld
# 25335       14          7
#
# [1 rows x 27 columns]
