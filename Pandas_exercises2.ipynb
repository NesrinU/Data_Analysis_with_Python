# %%
import pandas as pd

# %%
df= pd.read_csv('data.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.set_index('StockCode')    # belirttigimiz sütunu index olarak ayarlar.ama orjinal dosyayi degistirmez
# Out:
#           InvoiceNo                          Description  Quantity  \
# StockCode
# 85123A       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 71053        536365                  WHITE METAL LANTERN         6
# 84406B       536365       CREAM CUPID HEARTS COAT HANGER         8
# 84029G       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 84029E       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...             ...                                  ...       ...
# 22613        581587          PACK OF 20 SPACEBOY NAPKINS        12
# 22899        581587         CHILDREN'S APRON DOLLY GIRL          6
# 23254        581587        CHILDRENS CUTLERY DOLLY GIRL          4
# 23255        581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 22138        581587        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# StockCode
# 85123A      12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# df = df.set_index('StockCode')     yaparsak orjinal dosyayi degistirmis oluruz

# %%
# df.set_index('StockCode', inplace= True)    böyle yaparsak direk atamadan degistirmis oluruz

# %%
df.Description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
df["Description"]
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
df.loc[3567]
# Out:
# InvoiceNo                      536637
# StockCode                       22911
# Description    PAPER CHAIN KIT LONDON
# Quantity                            1
# InvoiceDate           12/2/2010 11:35
# UnitPrice                        2.95
# CustomerID                    18041.0
# Country                United Kingdom
# Name: 3567, dtype: object

# %%
df.loc[3567, 'Description']
# Out:
# 'PAPER CHAIN KIT LONDON'

# %%
df.iloc[0]
# Out:
# InvoiceNo                                  536365
# StockCode                                  85123A
# Description    WHITE HANGING HEART T-LIGHT HOLDER
# Quantity                                        6
# InvoiceDate                        12/1/2010 8:26
# UnitPrice                                    2.55
# CustomerID                                17850.0
# Country                            United Kingdom
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# InvoiceNo                                  536365
# StockCode                                  85123A
# Description    WHITE HANGING HEART T-LIGHT HOLDER
# Quantity                                        6
# InvoiceDate                        12/1/2010 8:26
# UnitPrice                                    2.55
# CustomerID                                17850.0
# Country                            United Kingdom
# Name: 0, dtype: object

# %%
df.iloc[0,2]
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
df.iloc[0:5]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.iloc[:5]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.iloc[-5:]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
df.iloc[:5, :3]
# Out:
#   InvoiceNo StockCode                          Description
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365     71053                  WHITE METAL LANTERN
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.

# %%
df['Country'] == "France"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904     True
# 541905     True
# 541906     True
# 541907     True
# 541908     True
# Name: Country, Length: 541909, dtype: bool

# %%
df[df['Country'] == "France"]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/2010 8:45       3.75     12583.0  France
# ...

# %%
df.loc[df['Country'] == "France"]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/2010 8:45       3.75     12583.0  France
# ...

# %%
df[df['Quantity'] > 25]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 9         536367     84879     ASSORTED COLOUR BIRD ORNAMENT        32
# 31        536370     10002       INFLATABLE POLITICAL GLOBE         48
# 44        536370     22492           MINI PAINT SET VINTAGE         36
# 46        536371     22086   PAPER CHAIN KIT 50'S CHRISTMAS         80
# 65        536374     21258        VICTORIAN SEWING BOX LARGE        32
# ...          ...       ...                               ...       ...
# 541835    581579     23581            JUMBO BAG PAISLEY PARK        40
# 541865    581583     20725           LUNCH BAG RED RETROSPOT        40
# 541866    581583     85038   6 CHOCOLATE LOVE HEART T-LIGHTS        36
# 541867    581584     20832  RED FLOCK LOVE HEART PHOTO FRAME        72
# 541868    581584     85038   6 CHOCOLATE LOVE HEART T-LIGHTS        48
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df['UnitPrice'].describe()
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
df['Country'].value_counts(normalize=True)          # oranini verir
# Out:
# United Kingdom          0.914320
# Germany                 0.017521
# France                  0.015790
# EIRE                    0.015124
# Spain                   0.004674
# Netherlands             0.004375
# Belgium                 0.003818
# Switzerland             0.003694
# Portugal                0.002803
# Australia               0.002323
# Norway                  0.002004
# Italy                   0.001482
# Channel Islands         0.001399
# Finland                 0.001283
# Cyprus                  0.001148
# Sweden                  0.000853
# Unspecified             0.000823
# Austria                 0.000740
# Denmark                 0.000718
# Japan                   0.000661
# Poland                  0.000629
# Israel                  0.000548
# USA                     0.000537
# Hong Kong               0.000531
# Singapore               0.000423
# Iceland                 0.000336
# Canada                  0.000279
# Greece                  0.000269
# ...

# %%
df['Quantity'].mean()
# Out:
# 9.55224954743324

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df['Quantity'].loc[df['Country']=="Germany"].mean()
# Out:
# 12.369457609268036

# %%
df['Country'].unique().tolist()
# Out:
# ['United Kingdom',
#  'France',
#  'Australia',
#  'Netherlands',
#  'Germany',
#  'Norway',
#  'EIRE',
#  'Switzerland',
#  'Spain',
#  'Poland',
#  'Portugal',
#  'Italy',
#  'Belgium',
#  'Lithuania',
#  'Japan',
#  'Iceland',
#  'Channel Islands',
#  'Denmark',
#  'Cyprus',
#  'Sweden',
#  'Austria',
#  'Israel',
#  'Finland',
#  'Bahrain',
#  'Greece',
#  'Hong Kong',
#  'Singapore',
#  'Lebanon',
#  'United Arab Emirates',
#  'Saudi Arabia',
#  'Czech Republic',
#  'Canada',
#  'Unspecified',
#  'Brazil',
#  'USA',
#  'European Community',
#  'Malta',
#  'RSA']

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
import numpy as np

# %%
 # df.iloc[50:55, 3]= np.NaN    bu aralikta degerleri siliyoruz 50inci satrdan 55. satira kdr 3. sütundaki degerler

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()       #her sütundakibos olan degerlerin toplam sayisini veriyor
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
len(df)
# Out:
# 541909

# %%
len(df['CustomerID'])
# Out:
# 541909
